# %%
import psycopg2 # драйвер для postgresql
import getpass  # прячем параль, чтобы не писать его в параметрах
import psycopg2
import getpass
import numpy as np
import datetime
import time
import pandas as pd
import dateutil.relativedelta as dr
conn=psycopg2.connect(user='postgres',
                      database='HW',
                      host='localhost',
                      port='5432',
                      password=getpass.getpass('Insert password: '))
# Out:
# Insert password: ········

# %%
query = """ SELECT *
            FROM (SELECT MAX("CPN") AS "CPN", "ISIN", max("BUYBACKDATE") AS "BUYBACKDATE",
                  max("BUYBACKPRICE") AS "BUYBACKPRICE"
                  FROM public.quotes_task
                  GROUP BY "ISIN") AS cpn
            INNER JOIN(SELECT "ISINCode", "FaceValue", "HaveOffer", "AmortisedMty", 
                       "CouponPerYear", "NumCoupons", "EndMtyDate", "CouponType", "IssuerName"
                       FROM public.bond_description_task
                       WHERE "Status"!='Погашен') AS bonds
            ON cpn."ISIN" = bonds."ISINCode" """

# %%
query = """ SELECT *
            FROM (SELECT MAX("CPN") AS "CPN", "ISIN", max("BUYBACKDATE") AS "BUYBACKDATE",
                  max("BUYBACKPRICE") AS "BUYBACKPRICE"
                  FROM public.quotes_task
                  GROUP BY "ISIN") AS cpn
            INNER JOIN(SELECT "ISINCode", "FaceValue", "HaveOffer", "AmortisedMty", 
                       "CouponPerYear", "NumCoupons", "EndMtyDate", "CouponType", "IssuerName"
                       FROM public.bond_description_task
                       WHERE "Status"!='Погашен') AS bonds
            ON cpn."ISIN" = bonds."ISINCode" """
          

# 3) Возвращаем матрицу платежей.
import pandas as pd
data = pd.read_sql_query(query, conn)
data = pd.DataFrame(data)
# data = data.drop(['ISINCode'], axis=1)
data
# data.head(10)
# Out:
#         CPN          ISIN BUYBACKDATE  BUYBACKPRICE      ISINCode  FaceValue  \
# 0     97.50  RU000A0JRYJ0        None           NaN  RU000A0JRYJ0     1000.0
# 1     24.56  RU000A0JTG34        None           NaN  RU000A0JTG34     1000.0
# 2     20.64  RU000A0JU823        None           NaN  RU000A0JU823     1000.0
# 3     29.29  RU000A0JUWK6        None           NaN  RU000A0JUWK6     1000.0
# 4     26.55  RU000A0JS1E8        None           NaN  RU000A0JS1E8     1000.0
# 5     24.31  RU000A0JTF68        None           NaN  RU000A0JTF68     1000.0
# 6     51.37  RU000A0JV3M2        None           NaN  RU000A0JV3M2     1000.0
# 7     39.89  RU000A0JRGR0        None           NaN  RU000A0JRGR0     1000.0
# 8     26.80  RU000A0JUP89        None           NaN  RU000A0JUP89     1000.0
# 9     34.76  RU000A0JUWU5        None           NaN  RU000A0JUWU5     1000.0
# 10    23.68  RU000A0JR6K5        None           NaN  RU000A0JR6K5     1000.0
# 11    24.11  RU000A0JSVC9        None           NaN  RU000A0JSVC9     1000.0
# 12    20.32  RU000A0JTK20        None           NaN  RU000A0JTK20     1000.0
# 13    19.70  RU000A0JTN01        None           NaN  RU000A0JTN01     1000.0
# 14    30.29  RU000A0JNGU3  2016-01-06         100.0  RU000A0JNGU3     1000.0
# 15    23.81  RU000A0JUQE1  2016-06-28         100.0  RU000A0JUQE1     1000.0
# 16    35.28  RU000A0JU773  2016-07-08         100.0  RU000A0JU773     1000.0
# 17    42.38  RU000A0JV3Q3  2015-12-25         100.0  RU000A0JV3Q3     1000.0
# 18    82.27  RU000A0JSVF2  2016-02-24         100.0  RU000A0JSVF2     1000.0
# 19    77.29  RU000A0JNZW9  2009-06-17         100.0  RU000A0JNZW9     1000.0
# 20    66.07  RU000A0JTY40  2016-06-01         100.0  RU000A0JTY40     1000.0
# 21    62.33  RU000A0JU7X1  2016-10-18         100.0  RU000A0JU7X1     1000.0
# 22    64.82  RU000A0JUGY0  2016-09-01         100.0  RU000A0JUGY0     1000.0
# 23    64.82  RU000A0JUPW5  2016-06-23         100.0  RU000A0JUPW5     1000.0
# 24    42.38  RU000A0JUPY1  2017-06-23         100.0  RU000A0JUPY1     1000.0
# 25    80.28  RU000A0JVBX1  2016-04-07         100.0  RU000A0JVBX1     1000.0
# 26    29.92  RU000A0JS7B1        None           NaN  RU000A0JS7B1     1000.0
# 27    29.92  RU000A0JS7C9        None           NaN  RU000A0JS7C9     1000.0
# 28    29.92  RU000A0JS8N4        None           NaN  RU000A0JS8N4     1000.0
# 29    20.07  RU000A0JTKK3        None           NaN  RU000A0JTKK3     1000.0
# ..      ...           ...         ...           ...           ...        ...
# 477   49.86  RU000A0JUWA7  2018-10-08         100.0  RU000A0JUWA7     1000.0
# 478   49.86  RU000A0JUWW1  2020-10-08         100.0  RU000A0JUWW1     1000.0
# 479   49.86  RU000A0JUX30  2020-10-13         100.0  RU000A0JUX30     1000.0
# 480   49.86  RU000A0JUXT5  2020-10-19         100.0  RU000A0JUXT5     1000.0
# 481   49.86  RU000A0JUYC9  2021-10-27         100.0  RU000A0JUYC9     1000.0
# 482   52.36  RU000A0JUZZ7  2021-11-15         100.0  RU000A0JUZZ7     1000.0
# 483   69.81  RU000A0JV4S7  2016-07-12         100.0  RU000A0JV4S7     1000.0
# 484   62.33  RU000A0JVPS1  2016-08-22         100.0  RU000A0JVPS1     1000.0
# 485   84.44  RU000A0JU5N6        None           NaN  RU000A0JU5N6     1000.0
# 486   71.05  RU000A0JTVE3  2016-04-15         100.0  RU000A0JTVE3     1000.0
# 487   59.84  RU000A0JUH97        None           NaN  RU000A0JUH97     1000.0
# 488  164.55  RU000A0JU9K4  2016-05-07         100.0  RU000A0JU9K4     1000.0
# 489  192.58  RU000A0JV0T3  2016-09-01         100.0  RU000A0JV0T3     1000.0
# 490   72.30  RU000A0JUBH6  2019-05-30         100.0  RU000A0JUBH6     1000.0
# 491   42.88  RU000A0JTMN3        None           NaN  RU000A0JTMN3     1000.0
# 492   42.88  RU000A0JTMP8        None           NaN  RU000A0JTMP8     1000.0
# 493   69.81  RU000A0JTP33        None           NaN  RU000A0JTP33     1000.0
# 494   69.81  RU000A0JTP58        None           NaN  RU000A0JTP58     1000.0
# 495   40.89  RU000A0JRSK0        None           NaN  RU000A0JRSK0     1000.0
# 496   40.39  RU000A0JUAJ4  2016-11-22         100.0  RU000A0JUAJ4     1000.0
# 497   52.36  RU000A0JUMJ9  2016-05-20         100.0  RU000A0JUMJ9     1000.0
# 498   52.36  RU000A0JUSH0  2016-08-09         100.0  RU000A0JUSH0     1000.0
# 499   59.84  RU000A0JV052  2015-11-25         100.0  RU000A0JV052     1000.0
# 500   32.41  RU000A0JTBH8        None           NaN  RU000A0JTBH8     1000.0
# 501   32.41  RU000A0JTBM8        None           NaN  RU000A0JTBM8     1000.0
# 502   29.92  RU000A0JTZ80  2015-06-19         100.0  RU000A0JTZ80     1000.0
# 503   29.92  RU000A0JTZA2  2015-06-19         100.0  RU000A0JTZA2     1000.0
# 504   29.92  RU000A0JTZB0  2015-06-19         100.0  RU000A0JTZB0     1000.0
# 505   23.68  RU000A0JRN60        None           NaN  RU000A0JRN60     1000.0
# 506   29.92  RU000A0JTGK1        None           NaN  RU000A0JTGK1     1000.0
#
#      HaveOffer  AmortisedMty  CouponPerYear  NumCoupons  EndMtyDate  \
# 0        False         False              2           9  2016-11-29
# 1        False          True              4          20  2017-12-17
# 2        False          True              4          20  2018-10-23
# 3        False          True              4          20  2019-10-14
# 4        False          True              4          20  2016-12-14
# 5        False          True              4          20  2017-12-05
# 6        False          True              4          20  2019-12-24
# 7        False          True              2          10  2016-05-04
# 8        False          True              4          20  2019-07-13
# 9        False          True              4          20  2019-10-10
# 10       False          True              4          20  2015-12-17
# 11       False          True              4          20  2017-08-23
# 12       False         False              4          12  2016-01-19
# 13       False         False              4          12  2016-02-16
# 14        True         False              4          40  2016-07-06
# 15        True         False              4          24  2020-06-23
# 16        True         False              4          40  2023-09-29
# 17        True         False              4          40  2024-12-13
# 18        True         False              2          10  2017-08-23
# 19        True         False              2           8  2010-12-15
# 20        True         False              2          10  2018-05-30
# 21        True         False              2          10  2018-10-16
# 22        True         False              2          10  2019-02-28
# 23        True         False              2          20  2024-06-13
# 24        True         False              2          20  2024-06-14
# 25        True         False              2          20  2025-03-27
# 26        True         False              4          12  2015-04-22
# 27        True         False              4          12  2015-04-22
# 28        True         False              4          12  2015-05-26
# 29       False         False              4          12  2016-01-28
# ..         ...           ...            ...         ...         ...
# 477       True         False              2          20  2024-09-30
# 478       True         False              2          20  2024-10-03
# 479       True         False              2          20  2024-10-08
# 480       True         False              2          20  2024-10-14
# 481       True         False              2          20  2024-10-23
# 482       True         False              2          20  2024-11-11
# 483       True         False              2          20  2024-12-31
# 484       True         False              2          20  2025-08-11
# 485       True         False              2           6  2016-09-19
# 486       True         False              2          14  2020-04-10
# 487       True         False              2          10  2019-03-06
# 488       True         False              1          10  2024-05-07
# 489      False          True              1          10  2025-06-01
# 490       True         False              2          18  2022-11-24
# 491      False         False              2           6  2016-02-11
# 492      False         False              2           6  2016-02-11
# 493       True         False              2           6  2016-02-23
# 494       True         False              2           6  2016-02-23
# 495      False         False              2          10  2016-09-07
# 496       True         False              2          10  2018-11-20
# 497       True         False              2          10  2019-05-17
# 498       True         False              2          10  2019-08-06
# 499       True         False              2          10  2019-11-20
# 500       True         False              4          12  2015-11-13
# 501       True         False              4          12  2015-11-13
# 502       True         False              4          12  2016-06-17
# 503       True         False              4          12  2016-06-17
# 504       True         False              4          12  2016-06-17
# 505       True         False              4          20  2016-07-21
# 506       True         False              4          12  2015-12-18
#
#         CouponType             IssuerName
# 0       Постоянный             Автодор ГК
# 1       Постоянный   Воронежская Обл Прав
# 2    Фиксированный   Воронежская Обл Прав
# 3       Постоянный   Воронежская Обл Прав
# 4       Постоянный   Вологодская Обл Прав
# 5       Постоянный   Вологодская Обл Прав
# 6       Постоянный           Волжский Адм
# 7    Фиксированный  Волгоградская Обл Адм
# 8    Фиксированный  Волгоградская Обл Адм
# 9    Фиксированный          Волгоград Адм
# 10   Фиксированный          Волгоград Адм
# 11   Фиксированный          Волгоград Адм
# 12      Постоянный               Банк ВТБ
# 13      Постоянный               Банк ВТБ
# 14      Переменный               Банк ВТБ
# 15      Переменный               Банк ВТБ
# 16      Переменный               Банк ВТБ
# 17      Переменный               Банк ВТБ
# 18      Переменный             Банк Зенит
# 19      Переменный               Вагонмаш
# 20      Переменный             Банк Зенит
# 21      Переменный             Банк Зенит
# 22      Переменный             Банк Зенит
# 23      Переменный             Банк Зенит
# 24      Переменный             Банк Зенит
# 25      Переменный             Банк Зенит
# 26      Переменный           ЮТэйр-Финанс
# 27      Переменный           ЮТэйр-Финанс
# 28      Переменный           ЮТэйр-Финанс
# 29      Постоянный        Банк Москвы АКБ
# ..             ...                    ...
# 477     Переменный             ТрансФин-М
# 478     Переменный             ТрансФин-М
# 479     Переменный             ТрансФин-М
# 480     Переменный             ТрансФин-М
# 481     Переменный             ТрансФин-М
# 482     Переменный             ТрансФин-М
# 483     Переменный             ТрансФин-М
# 484     Переменный             ТрансФин-М
# 485     Переменный                  УБРиР
# 486     Переменный                  УБРиР
# 487     Постоянный         УНИВЕР Капитал
# 488  Индексируемый    Управление отходами
# 489  Индексируемый    Управление отходами
# 490         Прочий        УралКапиталБанк
# 491     Постоянный         ЮниКредит Банк
# 492     Постоянный         ЮниКредит Банк
# 493     Переменный         ЮниКредит Банк
# 494     Переменный         ЮниКредит Банк
# 495     Постоянный         ЮниКредит Банк
# 496     Переменный         ЮниКредит Банк
# 497     Переменный         ЮниКредит Банк
# 498     Переменный         ЮниКредит Банк
# 499     Переменный         ЮниКредит Банк
# 500     Переменный           ЮТэйр-Финанс
# 501     Переменный           ЮТэйр-Финанс
# 502     Переменный           ЮТэйр-Финанс
# 503     Переменный           ЮТэйр-Финанс
# 504     Переменный           ЮТэйр-Финанс
# 505     Постоянный           ЮТэйр-Финанс
# 506     Переменный                   ЯТЭК
#
# [507 rows x 13 columns]

# %%
issuer = 'Воронежская Обл Прав'

data2 = data[data['IssuerName'] == issuer]
data2 = data2[['ISIN','EndMtyDate', 'CouponType', 'CPN', 'AmortisedMty']]
data2 = data2.sort_values(by="EndMtyDate", ascending=True)
data2
# Out:
#            ISIN  EndMtyDate     CouponType    CPN  AmortisedMty
# 1  RU000A0JTG34  2017-12-17     Постоянный  24.56          True
# 2  RU000A0JU823  2018-10-23  Фиксированный  20.64          True
# 3  RU000A0JUWK6  2019-10-14     Постоянный  29.29          True

# %%
import matplotlib.pyplot as plt

x_const = data2[data2['CouponType'] == 'Постоянный']['EndMtyDate']
y_const = data2[data2['CouponType'] == 'Постоянный']['CPN']

x_fixed = data2[data2['CouponType'] == 'Фиксированный']['EndMtyDate']
y_fixed = data2[data2['CouponType'] == 'Фиксированный']['CPN']

plt.bar(x_const, y_const, width = 10, label = 'Постоянный купон')
plt.bar(x_fixed, y_fixed, width = 10, label = 'Фиксированный купон')
plt.title('Купонные выплаты по облигациям ' + issuer)
plt.legend()

# %%
def hw3(issuer = 'Воронежская Обл Прав', path = '', table_name = None, fig_name = None):

    # 1) Подключаемся к БД.
    import psycopg2 # драйвер для postgresql
    import getpass  # прячем параль, чтобы не писать его в параметрах

    conn=psycopg2.connect(user='postgres',
                          database='HW',
                          host='localhost',
                          port='5432',
                          password=getpass.getpass('Insert password: ')
                            )
    query = """ SELECT *
            FROM (SELECT MAX("CPN") AS "CPN", "ISIN", max("BUYBACKDATE") AS "BUYBACKDATE",
                  max("BUYBACKPRICE") AS "BUYBACKPRICE"
                  FROM public.quotes_task
                  GROUP BY "ISIN") AS cpn
            INNER JOIN(SELECT "ISINCode", "FaceValue", "HaveOffer", "AmortisedMty", 
                       "CouponPerYear", "NumCoupons", "EndMtyDate", "CouponType", "IssuerName"
                       FROM public.bond_description_task
                       WHERE "Status"!='Погашен') AS bonds
            ON cpn."ISIN" = bonds."ISINCode" """
          

    # 3) Возвращаем матрицу платежей.
    import pandas as pd

    data = pd.read_sql_query(query, conn)
    data = pd.DataFrame(data)

    data2 = data[data['IssuerName'] == issuer]
    data2 = data2[['ISIN','EndMtyDate', 'CouponType', 'CPN', 'AmortisedMty']]
    data2 = data2.sort_values(by="EndMtyDate", ascending=True)
    
    table_name = 'Выплаты_' + issuer if table_name == None else table_name
    data2.to_csv(path + table_name + '.csv')
    
    import matplotlib.pyplot as plt

    x_const = data2[data2['CouponType'] == 'Постоянный']['EndMtyDate']
    y_const = data2[data2['CouponType'] == 'Постоянный']['CPN']

    x_fixed = data2[data2['CouponType'] == 'Фиксированный']['EndMtyDate']
    y_fixed = data2[data2['CouponType'] == 'Фиксированный']['CPN']

    plt.bar(x_const, y_const, width = 10, label = 'Постоянный купон')
    plt.bar(x_fixed, y_fixed, width = 10, label = 'Фиксированный купон')
    plt.title('Купонные выплаты по облигациям ' + issuer)
    plt.legend()
    
    fig_name = 'Выплаты_' + issuer if fig_name == None else fig_name
    
    plt.savefig(path + fig_name + '.png')
    
    a = {'table': data2, 'path': path, 'figname': fig_name}
    
    return(a)

# %%
issuer = 'Воронежская Обл Прав'
s = hw3(issuer)
s
# Out:
# Insert password: ········
# {'table':            ISIN  EndMtyDate     CouponType    CPN  AmortisedMty
#  1  RU000A0JTG34  2017-12-17     Постоянный  24.56          True
#  2  RU000A0JU823  2018-10-23  Фиксированный  20.64          True
#  3  RU000A0JUWK6  2019-10-14     Постоянный  29.29          True,
#  'path': '',
#  'figname': 'Выплаты_Воронежская Обл Прав'}

# %%
table = s['table']
path = s['path']
fig_name = s['figname']

# %%
from __future__ import print_function
from jinja2 import Environment, FileSystemLoader
from weasyprint import HTML, Document
import os

env = Environment(loader=FileSystemLoader('.'))
template = env.get_template("myreport.html") 
template_vars = {"title": "Отчет Составлен Жеткизгеновым Аскаром" + issuer,
                "INTRO": "Отчет содержит данные по выплатам облигаций компании Воронежская Обл Прав" + issuer, 
                 "TABLE_DESC": "Таблица 1. Выплаты "+issuer,
                 "TABLE": table.to_html(), 
                 "IMAGE_DESC": "Рисунок. Визуализация выплат", 
                 "IMAGE": os.path.realpath(path + fig_name + '.png')
                }
html_out = template.render(template_vars, presentational_hints=True)
HTML(string=html_out).write_pdf('Воронежская_Обл_Прав.pdf', presentational_hints=True)
#К сожалению, не получилось вывести отчёт, случилась такая же ошибка, как и на занятии.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-57-019eedd312f4> in <module>
#       1 from __future__ import print_function
#       2 from jinja2 import Environment, FileSystemLoader
# ----> 3 from weasyprint import HTML, Document
#       4 import os
#       5
#
# ~\Anaconda3\lib\site-packages\weasyprint\__init__.py in <module>
#     438
#     439 # Work around circular imports.
# --> 440 from .css import preprocess_stylesheet  # noqa isort:skip
#     441 from .html import (  # noqa isort:skip
#     442     HTML5_UA_STYLESHEET, HTML5_PH_STYLESHEET, find_base_url, get_html_metadata)
#
# ~\Anaconda3\lib\site-packages\weasyprint\css\__init__.py in <module>
#      28 from ..logger import LOGGER, PROGRESS_LOGGER
#      29 from ..urls import URLFetchingError, get_url_attribute, url_join
# ---> 30 from . import computed_values, media_queries
#      31 from .properties import INHERITED, INITIAL_NOT_COMPUTED, INITIAL_VALUES
#      32 from .utils import remove_whitespace
#
# ~\Anaconda3\lib\site-packages\weasyprint\css\computed_values.py in <module>
#      16 from tinycss2.color3 import parse_color
#      17
# ---> 18 from .. import text
#      19 from ..logger import LOGGER
#      20 from ..urls import get_link_attribute
#
# ~\Anaconda3\lib\site-packages\weasyprint\text.py in <module>
#      12 import re
#      13
# ---> 14 import cairocffi as cairo
#      15 import cffi
#      16 import pyphen
#
# ~\Anaconda3\lib\site-packages\cairocffi\__init__.py in <module>
#      48 cairo = dlopen(
#      49     ffi, ('cairo', 'libcairo-2'),
# ---> 50     ('libcairo.so', 'libcairo.2.dylib', 'libcairo-2.dll'))
#      51
#      52
#
# ~\Anaconda3\lib\site-packages\cairocffi\__init__.py in dlopen(ffi, library_names, filenames)
#      43     error_message = '\n'.join(  # pragma: no cover
#      44         str(exception) for exception in exceptions)
# ---> 45     raise OSError(error_message)  # pragma: no cover
#      46
#      47
#
# OSError: no library called "cairo" was found
# no library called "libcairo-2" was found
# cannot load library 'libcairo.so': error 0x7e
# cannot load library 'libcairo.2.dylib': error 0x7e
# cannot load library 'libcairo-2.dll': error 0x7e
